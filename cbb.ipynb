# %%
import pandas as pd
import os

# %%
file = 'Resources/cbb.csv'
file1 = 'Resources/cbb13.csv'
file2 = 'Resources/cbb14.csv'
file3 = 'Resources/cbb15.csv'
file4 = 'Resources/cbb16.csv'
file5 = 'Resources/cbb17.csv'
file6 = 'Resources/cbb18.csv'
file7 = 'Resources/cbb19.csv'
file8 = 'Resources/cbb20.csv'
file9 = 'Resources/cbb21.csv'

# %%
df = pd.read_csv(file)
df2013 = pd.read_csv(file1)
df2014 = pd.read_csv(file2)
df2015 = pd.read_csv(file3)
df2016 = pd.read_csv(file4)
df2017 = pd.read_csv(file5)
df2018 = pd.read_csv(file6)
df2019 = pd.read_csv(file7)
df2020 = pd.read_csv(file8)
df2021 = pd.read_csv(file9)

df2021.head()
# Out:
#        TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 0  Michigan  B10  24  20  118.1   91.1   0.9521   54.9   44.9  16.3  ...
# 1    Baylor  B12  24  22  123.2   94.5   0.9548   57.5   49.1  17.6  ...
# 2  Illinois  B10  29  23  117.7   90.4   0.9539   55.6   46.6  18.2  ...
# 3   Gonzaga  WCC  26  26  125.4   89.8   0.9791   61.0   47.5  16.1  ...
# 4      Iowa  B10  29  21  123.5   95.7   0.9491   54.6   48.3  13.3  ...
#
#     DRB   FTR  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T  WAB  SEED
# 0  24.8  28.9  24.5  53.3  42.3  38.7  33.5   66.9  7.2   1.0
# 1  30.9  27.0  31.7  54.1  48.1  41.8  34.0   68.8  6.6   1.0
# 2  22.2  39.2  30.5  55.3  45.4  37.6  32.7   70.7  8.9   1.0
# 3  23.4  36.7  25.9  64.0  46.8  36.5  32.5   74.6  8.5   1.0
# 4  28.6  32.0  22.6  52.4  45.8  38.6  34.8   70.0  5.6   2.0
#
# [5 rows x 22 columns]

# %%
df.sort_values(by=['YEAR'])
# Out:
#                     TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 2454  Florida Gulf Coast  ASun  35  24  103.4   96.3   0.6952   51.6   46.9
# 1932           Milwaukee  Horz  30   6   93.7  106.5   0.1871   44.6   50.5
# 1933             Hofstra   CAA  31   6   88.1  100.0   0.1890   42.0   48.9
# 1934            Longwood  BSth  31   6   93.5  114.2   0.0910   48.3   54.4
# 1935    SIU Edwardsville   OVC  25   7   90.4  106.4   0.1338   47.7   51.6
# ...                  ...   ...  ..  ..    ...    ...      ...    ...    ...
# 583            Charlotte  CUSA  29   8   95.0  107.7   0.1916   48.1   51.3
# 530       William & Mary   CAA  30  14  102.3  107.0   0.3733   54.4   52.7
# 529       UNC Wilmington   CAA  32  10  103.8  113.0   0.2734   50.5   56.0
# 587             Marshall  CUSA  37  23  105.5  106.0   0.4860   51.9   52.0
# 592                  UAB  CUSA  33  20  106.2  105.1   0.5307   50.4   49.4
#
# ...

# %%
df2020.insert(22, 'YEAR', 2020)
df2021.insert(22, 'YEAR', 2021)
df2021
# Out:
#                  TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0            Michigan   B10  24  20  118.1   91.1   0.9521   54.9   44.9
# 1              Baylor   B12  24  22  123.2   94.5   0.9548   57.5   49.1
# 2            Illinois   B10  29  23  117.7   90.4   0.9539   55.6   46.6
# 3             Gonzaga   WCC  26  26  125.4   89.8   0.9791   61.0   47.5
# 4                Iowa   B10  29  21  123.5   95.7   0.9491   54.6   48.3
# ..                ...   ...  ..  ..    ...    ...      ...    ...    ...
# 342    Louisiana Tech  CUSA  27  21  102.7   93.4   0.7479   50.5   45.6
# 343            Toledo   MAC  29  21  113.3  101.8   0.7743   54.3   48.3
# 344               UAB  CUSA  27  22  102.5   94.6   0.7153   48.6   47.0
# 345  Eastern Kentucky   OVC  27  22  101.5  102.3   0.4749   51.2   51.0
# 346           Belmont   OVC  29  26  108.5  101.6   0.6786   56.3   49.3
#
#       TOR  ...   FTR  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T  WAB  SEED  YEAR
# ...

# %%
df20 = df2020.append([df2021])
display(df20)
# Out:
#       RK              TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0    1.0            Kansas   B12  30  28  116.1   87.7   0.9616   53.7   43.7
# 1    2.0            Baylor   B12  30  26  114.5   88.4   0.9513   49.4   45.2
# 2    3.0           Gonzaga   WCC  33  31  121.3   94.3   0.9472   57.5   47.6
# 3    4.0            Dayton   A10  31  29  119.5   93.4   0.9445   59.7   46.6
# 4    5.0      Michigan St.   B10  31  22  114.8   91.3   0.9326   52.6   43.3
# ..   ...               ...   ...  ..  ..    ...    ...      ...    ...    ...
# 342  NaN    Louisiana Tech  CUSA  27  21  102.7   93.4   0.7479   50.5   45.6
# 343  NaN            Toledo   MAC  29  21  113.3  101.8   0.7743   54.3   48.3
# 344  NaN               UAB  CUSA  27  22  102.5   94.6   0.7153   48.6   47.0
# 345  NaN  Eastern Kentucky   OVC  27  22  101.5  102.3   0.4749   51.2   51.0
# 346  NaN           Belmont   OVC  29  26  108.5  101.6   0.6786   56.3   49.3
#
# ...

# %%
df20.reset_index(drop=True)
# Out:
#       RK              TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0    1.0            Kansas   B12  30  28  116.1   87.7   0.9616   53.7   43.7
# 1    2.0            Baylor   B12  30  26  114.5   88.4   0.9513   49.4   45.2
# 2    3.0           Gonzaga   WCC  33  31  121.3   94.3   0.9472   57.5   47.6
# 3    4.0            Dayton   A10  31  29  119.5   93.4   0.9445   59.7   46.6
# 4    5.0      Michigan St.   B10  31  22  114.8   91.3   0.9326   52.6   43.3
# ..   ...               ...   ...  ..  ..    ...    ...      ...    ...    ...
# 695  NaN    Louisiana Tech  CUSA  27  21  102.7   93.4   0.7479   50.5   45.6
# 696  NaN            Toledo   MAC  29  21  113.3  101.8   0.7743   54.3   48.3
# 697  NaN               UAB  CUSA  27  22  102.5   94.6   0.7153   48.6   47.0
# 698  NaN  Eastern Kentucky   OVC  27  22  101.5  102.3   0.4749   51.2   51.0
# 699  NaN           Belmont   OVC  29  26  108.5  101.6   0.6786   56.3   49.3
#
# ...

# %%
df = df.append([df20])
display(df)
# Out:
#                  TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0      North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1
# 1           Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7
# 2            Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7
# 3          Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0
# 4             Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1
# ..                ...   ...  ..  ..    ...    ...      ...    ...    ...
# 342    Louisiana Tech  CUSA  27  21  102.7   93.4   0.7479   50.5   45.6
# 343            Toledo   MAC  29  21  113.3  101.8   0.7743   54.3   48.3
# 344               UAB  CUSA  27  22  102.5   94.6   0.7153   48.6   47.0
# 345  Eastern Kentucky   OVC  27  22  101.5  102.3   0.4749   51.2   51.0
# 346           Belmont   OVC  29  26  108.5  101.6   0.6786   56.3   49.3
#
#       TOR  ...  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  \
# ...

# %%
df.reset_index(drop=True)
# Out:
#                   TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0       North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1
# 1            Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7
# 2             Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7
# 3           Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0
# 4              Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1
# ...                ...   ...  ..  ..    ...    ...      ...    ...    ...
# 3150    Louisiana Tech  CUSA  27  21  102.7   93.4   0.7479   50.5   45.6
# 3151            Toledo   MAC  29  21  113.3  101.8   0.7743   54.3   48.3
# 3152               UAB  CUSA  27  22  102.5   94.6   0.7153   48.6   47.0
# 3153  Eastern Kentucky   OVC  27  22  101.5  102.3   0.4749   51.2   51.0
# 3154           Belmont   OVC  29  26  108.5  101.6   0.6786   56.3   49.3
#
#        TOR  ...  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  \
# ...

# %%
df.sort_values(by=['YEAR'])
# Out:
#                    TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 1822  Boston University    AE  30  17  103.2  101.1   0.5570   52.2   47.4
# 1934           Longwood  BSth  31   6   93.5  114.2   0.0910   48.3   54.4
# 1935   SIU Edwardsville   OVC  25   7   90.4  106.4   0.1338   47.7   51.6
# 1936   Tennessee Martin   OVC  28   7   91.9  112.9   0.0861   43.3   53.5
# 1937            Seattle   WAC  29   7   92.5   97.1   0.3642   47.1   46.7
# ...                 ...   ...  ..  ..    ...    ...      ...    ...    ...
# 111           Loyola MD   Pat  17   6   97.7  100.9   0.4088   51.1   49.3
# 110   Cal St. Fullerton    BW  15   6  102.6  111.6   0.2758   51.2   54.9
# 109         Alabama A&M  SWAC  15   6   85.4  104.7   0.0878   44.8   44.0
# 117            Portland   WCC  18   6   97.6  112.2   0.1678   46.3   58.9
# 346             Belmont   OVC  29  26  108.5  101.6   0.6786   56.3   49.3
#
# ...

# %%
df.to_csv('Resources/cbb_combined.csv')
